# %%
# 필요한 라이브러리 임포트
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split  # train_test_split 임포트
from keras.models import Sequential
from keras.layers import LSTM, GRU, Dense, Dropout, Input  # Input 레이어 임포트

# 1. 데이터 수집
start = '2018-01-01'  # 데이터 시작 날짜
end = '2020-12-31'    # 데이터 종료 날짜
ticker = 'AAPL'       # 주식 티커
df = yf.download(ticker, start=start, end=end)  # yfinance를 사용하여 데이터 다운로드

# 2. 데이터 전처리
data = df['Close'].values.reshape(-1, 1)  # 종가를 2D 배열로 변형
scaler = MinMaxScaler(feature_range=(0, 1))  # 데이터 정규화
scaled_data = scaler.fit_transform(data)  # 데이터 정규화 수행

# 데이터셋 분할: 훈련 데이터와 테스트 데이터
train_data, test_data = train_test_split(scaled_data, test_size=0.2, shuffle=False)  # 20% 테스트 데이터

# LSTM/GRU 입력 형식에 맞게 데이터 변형
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])  # 입력 데이터
        y.append(data[i + time_step, 0])      # 타겟 데이터
    return np.array(X), np.array(y)

# 시간 단계 설정
time_step = 60  # 60일의 데이터를 사용하여 예측
X_train, y_train = create_dataset(train_data, time_step)  # 훈련 데이터 생성
X_test, y_test = create_dataset(test_data, time_step)      # 테스트 데이터 생성

# LSTM/GRU 입력 형태로 변형 (3D 배열)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)  # (samples, time steps, features)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# 3. LSTM 모델 구축
lstm_model = Sequential()  # Sequential 모델 초기화
lstm_model.add(Input(shape=(X_train.shape[1], 1)))  # Input 레이어 추가
lstm_model.add(LSTM(units=50, return_sequences=True))  # 첫 번째 LSTM 레이어
lstm_model.add(Dropout(0.2))  # 과적합 방지를 위한 Dropout
lstm_model.add(LSTM(units=50, return_sequences=False))  # 두 번째 LSTM 레이어
lstm_model.add(Dropout(0.2))  # 과적합 방지를 위한 Dropout
lstm_model.add(Dense(units=1))  # 최종 출력 레이어
lstm_model.compile(optimizer='adam', loss='mean_squared_error')  # 모델 컴파일
lstm_model.fit(X_train, y_train, epochs=100, batch_size=32)  # 모델 훈련

# 4. GRU 모델 구축
gru_model = Sequential()  # Sequential 모델 초기화
gru_model.add(Input(shape=(X_train.shape[1], 1)))  # Input 레이어 추가
gru_model.add(GRU(units=50, return_sequences=True))  # 첫 번째 GRU 레이어
gru_model.add(Dropout(0.2))  # 과적합 방지를 위한 Dropout
gru_model.add(GRU(units=50, return_sequences=False))  # 두 번째 GRU 레이어
gru_model.add(Dropout(0.2))  # 과적합 방지를 위한 Dropout
gru_model.add(Dense(units=1))  # 최종 출력 레이어
gru_model.compile(optimizer='adam', loss='mean_squared_error')  # 모델 컴파일
gru_model.fit(X_train, y_train, epochs=100, batch_size=32)  # 모델 훈련

# 5. 예측 수행
lstm_predicted_prices = lstm_model.predict(X_test)  # LSTM 예측
gru_predicted_prices = gru_model.predict(X_test)    # GRU 예측

# 예측 결과를 원래 스케일로 변환
lstm_predicted_prices = scaler.inverse_transform(lstm_predicted_prices)
gru_predicted_prices = scaler.inverse_transform(gru_predicted_prices)

# 6. 결과 시각화
plt.figure(figsize=(14, 7))
plt.plot(df.index[len(train_data) + time_step + 1:], lstm_predicted_prices, color='red', label='LSTM Predicted Price')  # LSTM 예측 결과
plt.plot(df.index[len(train_data) + time_step + 1:], gru_predicted_prices, color='green', label='GRU Predicted Price')  # GRU 예측 결과
plt.plot(df.index, data, color='blue', label='Actual Price')  # 실제 가격
plt.title(f'{ticker} Stock Price Prediction using LSTM and GRU')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0200
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0026
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0014
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0014
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0011
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0011
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0010
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 8.9659e-04
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0010
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.3533e-04
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 8.2182e-04
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0011
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 7.4871e-04
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0010
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.7565e-04
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 7.6783e-04
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 8.7579e-04
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 9.0892e-04
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.6472e-04
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.3910e-04
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.7277e-04
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.9297e-04
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.3366e-04
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0011
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.4844e-04
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.5315e-04
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.5087e-04
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.0226e-04
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 6.3390e-04
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.2003e-04
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.7783e-04
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.1888e-04
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 7.6223e-04
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.4996e-04
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.1417e-04
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 6.3768e-04
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 5.6465e-04
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.1191e-04
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.5641e-04
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 6.5161e-04
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 6.1942e-04
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.1515e-04
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.4012e-04
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 5.5952e-04
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.5523e-04
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.3574e-04
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.6351e-04
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.9558e-04
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.2043e-04
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.3172e-04
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.4153e-04
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 6.6000e-04
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.7349e-04
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.9124e-04
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.6388e-04
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.1317e-04
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.1127e-04
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.5367e-04
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.8469e-04
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.1761e-04
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 6.0686e-04
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.0732e-04
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.0542e-04
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.3254e-04
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.0104e-04
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.3830e-04
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.0237e-04
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.3029e-04
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.8529e-04
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.8923e-04
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.7950e-04
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.5010e-04
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.4433e-04
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.8554e-04
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.4993e-04
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.8226e-04
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.4273e-04
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.8178e-04
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.0992e-04
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.3502e-04
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.4820e-04
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.2361e-04
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.6716e-04
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.1621e-04
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.0755e-04
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.1726e-04
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 4.4214e-04
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.3893e-04
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.3612e-04
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.1225e-04
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.7440e-04
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.7210e-04
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.1096e-04
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.0917e-04
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.6680e-04
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 3.6640e-04
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.2101e-04
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 4.2111e-04
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.4805e-04
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.5505e-04
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0344
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0036
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0014
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.9119e-04
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.7040e-04
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 8.2815e-04
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 9.6492e-04
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.3779e-04
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.6064e-04
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.6740e-04
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.2185e-04
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 6.6355e-04
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.5204e-04
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 8.5341e-04
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.6556e-04
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.5581e-04
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.8636e-04
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.2276e-04
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 7.1187e-04
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 5.4714e-04
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.4053e-04
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.6229e-04
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.3016e-04
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.0295e-04
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.4602e-04
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.8359e-04
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.9694e-04
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.2631e-04
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.4429e-04
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.7631e-04
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.2101e-04
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.8968e-04
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.7164e-04
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.1248e-04
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 5.5648e-04
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.7711e-04
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.4776e-04
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.5143e-04
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.3146e-04
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.2568e-04
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.3600e-04
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.8489e-04
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.4881e-04
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.8039e-04
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.8535e-04
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.4284e-04
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.2207e-04
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.5736e-04
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.5147e-04
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.2066e-04
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.9064e-04
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.9929e-04
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.9218e-04
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.1923e-04
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.0029e-04
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.6144e-04
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.4139e-04
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.8732e-04
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.1828e-04
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.9692e-04
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.9374e-04
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 3.0832e-04
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.1208e-04
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.0816e-04
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.7911e-04
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.8935e-04
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.5726e-04
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.2565e-04
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.2046e-04
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.0350e-04
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.6585e-04
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.2093e-04
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.9762e-04
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 3.7709e-04
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.4175e-04
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.6514e-04
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.3359e-04
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 3.4242e-04
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.0528e-04
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.9846e-04
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.0313e-04
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.2509e-04
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.9369e-04
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.0627e-04
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.7367e-04
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.1778e-04
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.8295e-04
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.6975e-04
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.6626e-04
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.4284e-04
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.2966e-04
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.7903e-04
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.3687e-04
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.9587e-04
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.0972e-04
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 3.2966e-04
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.0770e-04
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.1782e-04
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.1556e-04
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.7180e-04
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step
