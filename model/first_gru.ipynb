# %%
# 필요한 라이브러리 임포트
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split  # train_test_split 임포트
from keras.models import Sequential
from keras.layers import GRU, Dense, Dropout, Input  # Input 레이어 임포트

# 1. 데이터 수집
start = '2022-10-01'  # 데이터 시작 날짜
end = '2024-10-01'    # 데이터 종료 날짜
ticker = 'NVDA'       # 주식 티커
df = yf.download(ticker, start=start, end=end)  # yfinance를 사용하여 데이터 다운로드

# 2. 데이터 전처리
data = df['Close'].values.reshape(-1, 1)  # 종가를 2D 배열로 변형
scaler = MinMaxScaler(feature_range=(0, 1))  # 데이터 정규화
scaled_data = scaler.fit_transform(data)  # 데이터 정규화 수행

# 데이터셋 분할: 훈련 데이터와 테스트 데이터
train_data, test_data = train_test_split(scaled_data, test_size=0.2, shuffle=False)  # 20% 테스트 데이터

# GRU 입력 형식에 맞게 데이터 변형
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step), 0])  # 입력 데이터
        y.append(data[i + time_step, 0])      # 타겟 데이터
    return np.array(X), np.array(y)

# 시간 단계 설정
time_step = 60  # 60일의 데이터를 사용하여 예측
X_train, y_train = create_dataset(train_data, time_step)  # 훈련 데이터 생성
X_test, y_test = create_dataset(test_data, time_step)      # 테스트 데이터 생성

# GRU 입력 형태로 변형 (3D 배열)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)  # (samples, time steps, features)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# 3. GRU 모델 구축
gru_model = Sequential()  # Sequential 모델 초기화
gru_model.add(Input(shape=(X_train.shape[1], 1)))  # Input 레이어 추가
gru_model.add(GRU(units=50, return_sequences=True))  # 첫 번째 GRU 레이어
gru_model.add(Dropout(0.2))  # 과적합 방지를 위한 Dropout
gru_model.add(GRU(units=50, return_sequences=False))  # 두 번째 GRU 레이어
gru_model.add(Dropout(0.2))  # 과적합 방지를 위한 Dropout
gru_model.add(Dense(units=1))  # 최종 출력 레이어
gru_model.compile(optimizer='adam', loss='mean_squared_error')  # 모델 컴파일
gru_model.fit(X_train, y_train, epochs=100, batch_size=32)  # 모델 훈련

# 4. 예측 수행
gru_predicted_prices = gru_model.predict(X_test)    # GRU 예측

# 예측 결과를 원래 스케일로 변환
gru_predicted_prices = scaler.inverse_transform(gru_predicted_prices)

# 5. 결과 시각화
plt.figure(figsize=(14, 7))
plt.plot(df.index[len(train_data) + time_step + 1:], gru_predicted_prices, color='green', label='GRU Predicted Price')  # GRU 예측 결과
plt.plot(df.index, data, color='blue', label='Actual Price')  # 실제 가격
plt.title(f'{ticker} Stock Price Prediction using GRU')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.legend()
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - loss: 0.0717
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 0.0151
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0068
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0025
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0018
# Epoch 6/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0017
# Epoch 7/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 0.0021
# Epoch 8/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0021
# Epoch 9/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0016
# Epoch 10/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0012
# Epoch 11/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0013
# Epoch 12/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 0.0015
# Epoch 13/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0012
# Epoch 14/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0014
# Epoch 15/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0014
# Epoch 16/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0011
# Epoch 17/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - loss: 0.0011
# Epoch 18/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0015
# Epoch 19/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0012
# Epoch 20/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0014
# Epoch 21/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 0.0012
# Epoch 22/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0014
# Epoch 23/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 0.0011
# Epoch 24/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0012
# Epoch 25/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 9.6397e-04
# Epoch 26/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 8.7968e-04
# Epoch 27/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0011
# Epoch 28/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0013
# Epoch 29/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 9.7073e-04
# Epoch 30/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0012
# Epoch 31/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 0.0011
# Epoch 32/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0011
# Epoch 33/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0012
# Epoch 34/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0010
# Epoch 35/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.0012
# Epoch 36/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0010
# Epoch 37/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0012
# Epoch 38/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0011
# Epoch 39/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0011
# Epoch 40/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 0.0012
# Epoch 41/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 0.0012
# Epoch 42/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 8.8938e-04
# Epoch 43/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - loss: 0.0010
# Epoch 44/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - loss: 9.6877e-04
# Epoch 45/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 0.0011
# Epoch 46/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 7.8240e-04
# Epoch 47/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 8.7143e-04
# Epoch 48/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 8.6200e-04
# Epoch 49/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0010
# Epoch 50/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 9.9517e-04
# Epoch 51/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 7.7136e-04
# Epoch 52/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0011
# Epoch 53/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0010
# Epoch 54/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0010
# Epoch 55/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 6.4748e-04
# Epoch 56/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 6.7719e-04
# Epoch 57/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0011
# Epoch 58/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 8.4837e-04
# Epoch 59/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0010
# Epoch 60/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 9.1611e-04
# Epoch 61/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 8.2696e-04
# Epoch 62/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 8.5652e-04
# Epoch 63/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 9.7690e-04
# Epoch 64/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 7.5405e-04
# Epoch 65/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0011
# Epoch 66/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 7.1771e-04
# Epoch 67/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 7.3742e-04
# Epoch 68/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 6.9628e-04
# Epoch 69/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 8.7738e-04
# Epoch 70/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 9.2134e-04
# Epoch 71/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0012
# Epoch 72/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 7.5560e-04
# Epoch 73/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0011
# Epoch 74/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 8.4098e-04
# Epoch 75/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 6.4520e-04
# Epoch 76/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 9.0556e-04
# Epoch 77/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 9.3189e-04
# Epoch 78/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0010
# Epoch 79/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 8.9020e-04
# Epoch 80/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 9.3971e-04
# Epoch 81/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 8.1350e-04
# Epoch 82/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 7.2778e-04
# Epoch 83/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 8.6524e-04
# Epoch 84/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 6.8793e-04
# Epoch 85/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 7.9272e-04
# Epoch 86/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 9.0808e-04
# Epoch 87/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 7.4952e-04
# Epoch 88/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 8.6853e-04
# Epoch 89/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0011
# Epoch 90/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 7.2075e-04
# Epoch 91/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 5.7397e-04
# Epoch 92/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 6.2505e-04
# Epoch 93/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0010
# Epoch 94/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0012
# Epoch 95/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 9.6108e-04
# Epoch 96/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 7.9680e-04
# Epoch 97/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 6.7745e-04
# Epoch 98/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 7.6410e-04
# Epoch 99/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 7.4455e-04
# Epoch 100/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 7.6736e-04
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step
